# %%
import matplotlib.pyplot as plt
import pandas as pd
import numpy as np
import requests
import time
from api_keys import weather_api_key
# Incorporated citipy to determine city based on latitude and longitude
from citipy import citipy

# %%
# Generate a random list of cities
lat_lngs = []
cities = []
# Create a set of random lat and lng combinations
lats = np.random.uniform(low=-90.000, high=90.000, size=1500)
lngs = np.random.uniform(low=-180.000, high=180.000, size=1500)
lat_lngs = zip(lats, lngs)
# Identify nearest city for each lat, lng combination
for lat_lng in lat_lngs:
    city = citipy.nearest_city(lat_lng[0], lat_lng[1]).city_name
    # If the city is unique, then add it to the cities list
    if city not in cities:
        cities.append(city)
# Print the city count to confirm sufficient count
len(cities)
# Out:
# 630

# %%
#See the structure of the info
url = 'https://api.openweathermap.org/data/2.5/weather?'
query_url = url + 'q=' + "miami" + '&appid=' + weather_api_key
data = requests.get(query_url).json()
print (data)
# Out:
# {'coord': {'lon': -80.19, 'lat': 25.77}, 'weather': [{'id': 500, 'main': 'Rain', 'description': 'light rain', 'icon': '10n'}], 'base': 'stations', 'main': {'temp': 298.06, 'feels_like': 297.97, 'temp_min': 297.15, 'temp_max': 298.71, 'pressure': 1016, 'humidity': 83}, 'visibility': 16093, 'wind': {'speed': 6.7, 'deg': 60}, 'rain': {'1h': 0.25}, 'clouds': {'all': 90}, 'dt': 1589516971, 'sys': {'type': 1, 'id': 4896, 'country': 'US', 'sunrise': 1589538895, 'sunset': 1589587171}, 'timezone': -14400, 'id': 4164138, 'name': 'Miami', 'cod': 200}

# %%
final_cities_list = []
country = []
date = []
lat = []
lng = []
humidity = []
cloudiness = []
max_temp = []
wind_speed = []

url = 'https://api.openweathermap.org/data/2.5/weather?'
print("-----------------------------")
print("Beginning Data Retrieval")
print("-----------------------------")
for i in cities:
    query_url = url + 'q=' + i + '&appid=' + weather_api_key
    data = requests.get(query_url).json()
    if(data['cod'] == 200):
        print("Processing data of " + str(i))
        final_cities_list.append(i)   
        country.append(data['sys']['country'])
        date.append(data['dt'])
        lat.append(data['coord']['lat'])
        lng.append(data['coord']['lon'])
        humidity.append(data['main']['humidity'])
        cloudiness.append(data['clouds']['all'])
        max_temp.append(data['main']['temp_max'])
        wind_speed.append(data['wind']['speed'])
    else:
        print("City not found. Skipping...")
print("-----------------------------")
print("Data Retreival complete")
print(f"Final list have {len(final_cities_list)} cities.")
print("-----------------------------")
# Out:
# -----------------------------
# Beginning Data Retrieval
# -----------------------------
# Processing data of lima
# Processing data of fortuna
# Processing data of kapaa
# Processing data of jamestown
# City not found. Skipping...
# Processing data of butaritari
# Processing data of mataura
# Processing data of carnarvon
# Processing data of ushuaia
# Processing data of punta arenas
# Processing data of hilo
# Processing data of tuktoyaktuk
# Processing data of longyearbyen
# Processing data of east london
# City not found. Skipping...
# Processing data of khatanga
# Processing data of paris
# Processing data of saint-joseph
# Processing data of sobolevo
# Processing data of margate
# Processing data of alice springs
# Processing data of yangambi
# Processing data of jurm
# Processing data of purranque
# Processing data of albany
# Processing data of upernavik
# Processing data of zhigansk
# Processing data of talnakh
# Processing data of cherskiy
# Processing data of sorland
# City not found. Skipping...
# Processing data of atuona
# Processing data of iralaya
# Processing data of norman wells
# Processing data of szekesfehervar
# Processing data of rikitea
# Processing data of bilibino
# Processing data of port blair
# Processing data of hasaki
# Processing data of la sarre
# Processing data of kungurtug
# Processing data of avarua
# Processing data of ilulissat
# Processing data of severo-kurilsk
# Processing data of kloulklubed
# Processing data of huarmey
# Processing data of enshi
# Processing data of henties bay
# City not found. Skipping...
# Processing data of kaitangata
# Processing data of arraial do cabo
# Processing data of castro
# City not found. Skipping...
# Processing data of bosaso
# Processing data of bonga
# Processing data of mindelo
# Processing data of voh
# Processing data of mahebourg
# Processing data of qaanaaq
# Processing data of george town
# Processing data of cape town
# Processing data of karasburg
# Processing data of barabai
# Processing data of caravelas
# Processing data of broken hill
# City not found. Skipping...
# Processing data of kruisfontein
# Processing data of kahului
# Processing data of matagami
# Processing data of pombia
# Processing data of anchorage
# Processing data of ribeira grande
# Processing data of puerto ayora
# Processing data of sao felix do xingu
# Processing data of chak
# Processing data of dikson
# Processing data of sterlibashevo
# Processing data of bethel
# Processing data of lata
# Processing data of luganville
# Processing data of logan
# Processing data of virginia beach
# Processing data of yellowknife
# Processing data of clyde river
# Processing data of asau
# Processing data of bathsheba
# Processing data of yumaguzino
# Processing data of quesnel
# Processing data of yulara
# Processing data of belaya gora
# City not found. Skipping...
# Processing data of blairmore
# Processing data of mandalgovi
# Processing data of kirkuk
# Processing data of port alfred
# Processing data of dakar
# Processing data of kyakhta
# Processing data of provideniya
# Processing data of maceio
# City not found. Skipping...
# Processing data of alta floresta
# Processing data of lorengau
# Processing data of maldonado
# Processing data of lagoa
# Processing data of butterworth
# City not found. Skipping...
# Processing data of faanui
# Processing data of hobart
# City not found. Skipping...
# Processing data of bluff
# Processing data of souillac
# Processing data of misratah
# Processing data of moratuwa
# Processing data of kodiak
# Processing data of filadelfia
# Processing data of padang
# Processing data of busselton
# Processing data of grenfell
# Processing data of laje
# Processing data of gizo
# Processing data of ponta do sol
# Processing data of nikolskoye
# Processing data of geraldton
# Processing data of baykit
# Processing data of klyuchi
# City not found. Skipping...
# Processing data of mamallapuram
# Processing data of kalmunai
# Processing data of new norfolk
# Processing data of vaini
# Processing data of nanortalik
# Processing data of san cristobal
# Processing data of westport
# Processing data of sibolga
# Processing data of sioux lookout
# City not found. Skipping...
# Processing data of thiadiaye
# Processing data of honningsvag
# Processing data of hermanus
# Processing data of hohhot
# Processing data of vaitape
# Processing data of chuy
# Processing data of harper
# Processing data of pervomayskoye
# Processing data of yar-sale
# Processing data of port macquarie
# Processing data of dunkirk
# Processing data of saint-pierre
# Processing data of tasiilaq
# Processing data of calabozo
# Processing data of dingzhou
# Processing data of ukiah
# Processing data of palo alto
# Processing data of arman
# Processing data of namanyere
# Processing data of okato
# Processing data of soderhamn
# Processing data of sumbe
# City not found. Skipping...
# City not found. Skipping...
# Processing data of krasnoselkup
# Processing data of kondinskoye
# Processing data of mokobeng
# Processing data of airai
# Processing data of hualmay
# Processing data of ugoofaaru
# Processing data of sedro-woolley
# Processing data of urucara
# Processing data of zwedru
# City not found. Skipping...
# Processing data of batticaloa
# Processing data of port elizabeth
# Processing data of russell
# Processing data of port lincoln
# Processing data of koslan
# Processing data of alofi
# City not found. Skipping...
# Processing data of shingu
# Processing data of saldanha
# Processing data of nuuk
# Processing data of richards bay
# Processing data of launceston
# City not found. Skipping...
# Processing data of codrington
# Processing data of shache
# Processing data of ekibastuz
# Processing data of hami
# Processing data of parnamirim
# Processing data of bengkulu
# Processing data of quatre cocos
# City not found. Skipping...
# Processing data of mehamn
# Processing data of brae
# Processing data of hervey bay
# Processing data of cap malheureux
# Processing data of nouadhibou
# Processing data of pisco
# Processing data of hithadhoo
# Processing data of pacific grove
# Processing data of tautira
# Processing data of idlib
# City not found. Skipping...
# Processing data of takaka
# Processing data of iqaluit
# City not found. Skipping...
# Processing data of sijunjung
# City not found. Skipping...
# Processing data of neiafu
# Processing data of casino
# Processing data of faya
# Processing data of deputatskiy
# Processing data of granada
# Processing data of caraquet
# Processing data of carlos antonio lopez
# City not found. Skipping...
# Processing data of bima
# Processing data of salalah
# Processing data of hoquiam
# Processing data of saint-philippe
# Processing data of araouane
# Processing data of kovur
# Processing data of ghanzi
# Processing data of lebu
# Processing data of olafsvik
# City not found. Skipping...
# City not found. Skipping...
# Processing data of sorochinsk
# Processing data of lovington
# Processing data of popesti
# Processing data of san andres
# Processing data of bonavista
# Processing data of aksha
# Processing data of guerrero negro
# Processing data of pula
# Processing data of torbay
# Processing data of saint-augustin
# Processing data of san patricio
# Processing data of catamarca
# City not found. Skipping...
# Processing data of rabo de peixe
# City not found. Skipping...
# Processing data of mecca
# Processing data of tual
# Processing data of sao joao da barra
# Processing data of olginskaya
# Processing data of tsevie
# Processing data of wattegama
# Processing data of pangkalanbuun
# Processing data of qaqortoq
# Processing data of northam
# Processing data of rundu
# Processing data of haines junction
# Processing data of esperance
# Processing data of sai buri
# Processing data of palmer
# Processing data of comodoro rivadavia
# Processing data of vestmanna
# Processing data of japura
# Processing data of flin flon
# Processing data of liverpool
# Processing data of berezovyy
# Processing data of praia da vitoria
# Processing data of isangel
# Processing data of gazojak
# Processing data of makakilo city
# Processing data of jiexiu
# Processing data of yaan
# Processing data of kavaratti
# Processing data of camana
# Processing data of kavieng
# Processing data of westerland
# Processing data of lamu
# Processing data of pundaguitan
# Processing data of hoima
# Processing data of ahipara
# Processing data of codajas
# Processing data of panji
# Processing data of carndonagh
# Processing data of thompson
# City not found. Skipping...
# Processing data of homer
# Processing data of mount gambier
# Processing data of ayagoz
# Processing data of grand gaube
# Processing data of klaksvik
# Processing data of dingle
# Processing data of suba
# Processing data of mangrol
# Processing data of najran
# Processing data of huilong
# City not found. Skipping...
# Processing data of kysyl-syr
# Processing data of sitka
# Processing data of victoria
# Processing data of hambantota
# Processing data of jungapeo
# Processing data of guican
# Processing data of tommot
# Processing data of new london
# Processing data of caxias
# Processing data of lucea
# Processing data of ust-kut
# Processing data of turkistan
# Processing data of saint anthony
# City not found. Skipping...
# Processing data of great malvern
# Processing data of jalu
# Processing data of batemans bay
# Processing data of hobyo
# Processing data of tumut
# Processing data of kisangani
# Processing data of chilliwack
# Processing data of kidal
# Processing data of rocha
# Processing data of georgetown
# Processing data of raahe
# Processing data of kabale
# Processing data of pevek
# Processing data of anadyr
# Processing data of namatanai
# Processing data of mwinilunga
# Processing data of sabang
# City not found. Skipping...
# Processing data of acapulco
# Processing data of haghartsin
# Processing data of traverse city
# Processing data of udachnyy
# City not found. Skipping...
# Processing data of saint george
# Processing data of katsuura
# Processing data of nador
# Processing data of impfondo
# Processing data of nichinan
# Processing data of atar
# Processing data of komsomolskiy
# Processing data of warrington
# Processing data of bambous virieux
# Processing data of bredasdorp
# Processing data of naze
# Processing data of katherine
# Processing data of moanda
# Processing data of zigong
# Processing data of concordia
# Processing data of balkhash
# Processing data of jagdalpur
# Processing data of wukari
# Processing data of basco
# City not found. Skipping...
# Processing data of ngawen
# Processing data of ixtapa
# Processing data of port keats
# Processing data of coquimbo
# Processing data of yanaul
# Processing data of genhe
# Processing data of chipinge
# Processing data of leopold
# City not found. Skipping...
# Processing data of freeport
# City not found. Skipping...
# Processing data of nelson bay
# Processing data of krasnoarmeysk
# Processing data of betioky
# Processing data of fort nelson
# Processing data of fairbanks
# Processing data of champaign
# Processing data of kyren
# City not found. Skipping...
# Processing data of sept-iles
# Processing data of tagusao
# Processing data of beyneu
# Processing data of saskylakh
# Processing data of mwaro
# Processing data of vedeno
# Processing data of aleksandrov gay
# Processing data of todos santos
# City not found. Skipping...
# Processing data of rosetta
# Processing data of lagunas
# Processing data of falam
# Processing data of ayan
# Processing data of nongstoin
# Processing data of vestmannaeyjar
# Processing data of mar del plata
# Processing data of sakakah
# Processing data of blackwater
# Processing data of port hardy
# Processing data of hovd
# Processing data of bara
# Processing data of beira
# Processing data of inirida
# Processing data of ocean city
# Processing data of kissidougou
# Processing data of paamiut
# Processing data of tiksi
# Processing data of puquio
# Processing data of coevorden
# Processing data of santander
# Processing data of kotovo
# Processing data of constantine
# Processing data of santo tomas
# Processing data of neustadt
# Processing data of narsaq
# Processing data of tianpeng
# Processing data of shakawe
# City not found. Skipping...
# Processing data of sambava
# Processing data of barrow
# Processing data of pucallpa
# Processing data of tessalit
# Processing data of areka
# Processing data of tres arroyos
# Processing data of berdigestyakh
# Processing data of chumikan
# Processing data of sitio novo do tocantins
# Processing data of mandal
# Processing data of moree
# Processing data of sehithwa
# Processing data of almeirim
# Processing data of robat karim
# City not found. Skipping...
# Processing data of barinitas
# City not found. Skipping...
# City not found. Skipping...
# Processing data of athabasca
# Processing data of morant bay
# Processing data of poum
# Processing data of puerto del rosario
# Processing data of rafai
# City not found. Skipping...
# Processing data of ponta delgada
# Processing data of tuatapere
# Processing data of tromso
# Processing data of lazarev
# Processing data of luderitz
# Processing data of tura
# City not found. Skipping...
# Processing data of kawalu
# City not found. Skipping...
# Processing data of baghdad
# Processing data of ilhabela
# Processing data of sivaki
# City not found. Skipping...
# Processing data of jamame
# Processing data of whitianga
# Processing data of tulum
# Processing data of eyl
# Processing data of vanimo
# Processing data of hofn
# Processing data of avera
# Processing data of los llanos de aridane
# Processing data of cayenne
# Processing data of inta
# City not found. Skipping...
# Processing data of vardo
# Processing data of isiolo
# Processing data of ouegoa
# Processing data of cabo san lucas
# City not found. Skipping...
# City not found. Skipping...
# Processing data of kuito
# Processing data of bac lieu
# Processing data of ntcheu
# Processing data of thinadhoo
# Processing data of thanh hoa
# Processing data of umm kaddadah
# Processing data of sabancuy
# Processing data of santa cruz
# Processing data of redwater
# Processing data of mnogovershinnyy
# Processing data of gunjur
# Processing data of yauya
# Processing data of asfi
# Processing data of san dionisio del mar
# Processing data of edd
# Processing data of tigil
# Processing data of asmara
# Processing data of abu samrah
# City not found. Skipping...
# Processing data of amapa
# Processing data of morgan city
# Processing data of half moon bay
# Processing data of praya
# City not found. Skipping...
# Processing data of san felipe
# City not found. Skipping...
# Processing data of mackay
# Processing data of saryozek
# Processing data of sibut
# City not found. Skipping...
# Processing data of guaruja
# City not found. Skipping...
# Processing data of ndola
# Processing data of narasannapeta
# Processing data of yantzaza
# Processing data of aranos
# Processing data of yuancheng
# City not found. Skipping...
# Processing data of imbituba
# Processing data of syumsi
# Processing data of prokopion
# Processing data of belchatow
# Processing data of sfantu gheorghe
# Processing data of bull savanna
# Processing data of aswan
# City not found. Skipping...
# Processing data of marzuq
# Processing data of agadez
# Processing data of tra vinh
# Processing data of el rosario
# Processing data of tigzirt
# Processing data of goderich
# Processing data of chokurdakh
# Processing data of shimoda
# Processing data of muros
# Processing data of niquero
# Processing data of conceicao da barra
# Processing data of aksarka
# Processing data of waddan
# Processing data of bacungan
# Processing data of kopayhorod
# City not found. Skipping...
# Processing data of san carlos
# Processing data of labuhan
# Processing data of nome
# Processing data of buenos aires
# Processing data of marseille
# Processing data of havelock
# Processing data of tamiahua
# Processing data of bouca
# Processing data of zyryanovsk
# Processing data of okrika
# Processing data of hamilton
# Processing data of dongsheng
# Processing data of natalio
# Processing data of kodinsk
# Processing data of tamandare
# Processing data of george
# Processing data of victor harbor
# Processing data of plainview
# Processing data of nanga eboko
# Processing data of bayshore gardens
# Processing data of raton
# Processing data of broome
# Processing data of prado
# Processing data of rakovski
# Processing data of ornskoldsvik
# Processing data of grand-santi
# Processing data of malakal
# Processing data of port hedland
# Processing data of itoman
# Processing data of suntar
# Processing data of randazzo
# Processing data of big rapids
# Processing data of flinders
# Processing data of ludvika
# Processing data of puri
# Processing data of merauke
# Processing data of seka
# Processing data of college
# City not found. Skipping...
# Processing data of nicoya
# Processing data of gayeri
# Processing data of straumen
# Processing data of san alberto
# Processing data of leningradskiy
# Processing data of dunedin
# Processing data of emerald
# Processing data of houlton
# Processing data of nanhai
# Processing data of aykhal
# Processing data of san policarpo
# Processing data of nueva loja
# Processing data of krishnarajasagara
# Processing data of vygonichi
# Processing data of buchanan
# Processing data of taoudenni
# Processing data of roma
# Processing data of camacha
# Processing data of taksimo
# City not found. Skipping...
# Processing data of baie-comeau
# Processing data of mandurah
# Processing data of berlevag
# Processing data of springbok
# Processing data of bhatkal
# Processing data of benguela
# Processing data of beloha
# Processing data of leshukonskoye
# Processing data of burnie
# Processing data of portmore
# Processing data of valparaiso
# Processing data of hay river
# Processing data of yima
# Processing data of quelimane
# City not found. Skipping...
# Processing data of lavrentiya
# Processing data of adrar
# City not found. Skipping...
# Processing data of kuznetsk
# Processing data of le port
# Processing data of dire
# Processing data of sherlovaya gora
# Processing data of marsa matruh
# Processing data of ati
# Processing data of campo de criptana
# Processing data of zima
# Processing data of juneau
# Processing data of lashio
# Processing data of rasulabad
# Processing data of ola
# Processing data of nantucket
# Processing data of palia kalan
# Processing data of tokur
# Processing data of kyrksaeterora
# Processing data of appleton
# Processing data of cocobeach
# Processing data of kostomuksha
# City not found. Skipping...
# Processing data of frankfort
# City not found. Skipping...
# Processing data of banda aceh
# Processing data of banjar
# Processing data of mogadishu
# Processing data of calmar
# Processing data of ambon
# Processing data of bouna
# Processing data of agadir
# Processing data of ancud
# City not found. Skipping...
# Processing data of taunggyi
# -----------------------------
# Data Retreival complete
# Final list have 568 cities.
# -----------------------------

# %%
cities_dict = {}
cities_dict = list(zip(final_cities_list,country,
                       date,lat,lng,
                       humidity,cloudiness,max_temp,wind_speed))
df = pd.DataFrame(cities_dict,columns=['City','Country',
                                       'Date','Lat','Lng',
                                       'Humidity','Cloudiness','Max Temp','Wind Speed'])
df.head()
# Out:
#          City Country        Date    Lat     Lng  Humidity  Cloudiness  \
# 0        lima      PE  1589522207 -12.04  -77.03        88          90
# 1     fortuna      US  1589522797  40.60 -124.16        93           1
# 2       kapaa      US  1589522797  22.08 -159.32        78           1
# 3   jamestown      US  1589522572  42.10  -79.24       100          90
# 4  butaritari      KI  1589522800   3.07  172.79        70           9
#
#    Max Temp  Wind Speed
# 0    291.15        3.60
# 1    284.26        0.99
# 2    297.15        2.10
# 3    288.15        4.60
# 4    301.74        2.30

# %%
# Date is in Unix Timestamp, so it have to be converted into DateTime
#df['DateTime_ms'] = pd.to_datetime(df['Date'],unit ='ms')
#df['DateTime_ns'] = pd.to_datetime(df['Date'],unit ='ns')
df['Date'] = pd.to_datetime(df['Date'],unit ='s')
#df['Date'] =  pd.to_datetime(df['Date']).dt.date
df['Date'] =  df['Date'].dt.date
df.head()
# Out:
#          City Country        Date    Lat     Lng  Humidity  Cloudiness  \
# 0        lima      PE  2020-05-15 -12.04  -77.03        88          90
# 1     fortuna      US  2020-05-15  40.60 -124.16        93           1
# 2       kapaa      US  2020-05-15  22.08 -159.32        78           1
# 3   jamestown      US  2020-05-15  42.10  -79.24       100          90
# 4  butaritari      KI  2020-05-15   3.07  172.79        70           9
#
#    Max Temp  Wind Speed
# 0    291.15        3.60
# 1    284.26        0.99
# 2    297.15        2.10
# 3    288.15        4.60
# 4    301.74        2.30

# %% [markdown]
# ## Latitude vs Temperature

# %%
plt.scatter(lat,max_temp,
            edgecolor="black", linewidths=1, marker="o", alpha=0.5, label="Cities")
plt.title("City Latitude vs. Max Temperature (%s)" % time.strftime("%d/%m/%Y"))
plt.ylabel("Max Temperature (F)")
plt.xlabel("Latitude")
plt.grid(True)

# Save the figure
plt.savefig("output/Lat-MaxTemp.png")
plt.show()

# %% [markdown]
# ## Missing things :
# * Graphs
# * Save DF in csv
