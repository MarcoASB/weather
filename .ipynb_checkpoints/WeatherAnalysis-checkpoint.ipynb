# %%
import matplotlib.pyplot as plt
import pandas as pd
import numpy as np
import requests
import time
from api_keys import weather_api_key
# Incorporated citipy to determine city based on latitude and longitude
from citipy import citipy

# %%
# Generate a random list of cities
lat_lngs = []
cities = []
# Create a set of random lat and lng combinations
lats = np.random.uniform(low=-90.000, high=90.000, size=1500)
lngs = np.random.uniform(low=-180.000, high=180.000, size=1500)
lat_lngs = zip(lats, lngs)
# Identify nearest city for each lat, lng combination
for lat_lng in lat_lngs:
    city = citipy.nearest_city(lat_lng[0], lat_lng[1]).city_name
    # If the city is unique, then add it to the cities list
    if city not in cities:
        cities.append(city)
# Print the city count to confirm sufficient count
len(cities)
# Out:
# 617

# %%
#See the structure of the info
url = 'https://api.openweathermap.org/data/2.5/weather?'
query_url = url + 'q=' + "miami" + '&appid=' + weather_api_key
data = requests.get(query_url).json()
print (data)
# Out:
# {'coord': {'lon': -80.19, 'lat': 25.77}, 'weather': [{'id': 804, 'main': 'Clouds', 'description': 'overcast clouds', 'icon': '04n'}], 'base': 'stations', 'main': {'temp': 297.6, 'feels_like': 296.17, 'temp_min': 297.04, 'temp_max': 298.15, 'pressure': 1020, 'humidity': 65}, 'visibility': 16093, 'wind': {'speed': 5.7, 'deg': 60, 'gust': 10.3}, 'clouds': {'all': 90}, 'dt': 1589435312, 'sys': {'type': 1, 'id': 4896, 'country': 'US', 'sunrise': 1589452525, 'sunset': 1589500738}, 'timezone': -14400, 'id': 4164138, 'name': 'Miami', 'cod': 200}

# %%
final_cities_list = []
country = []
date = []
lat = []
lng = []
humidity = []
cloudiness = []
max_temp = []
wind_speed = []

url = 'https://api.openweathermap.org/data/2.5/weather?'
print("-----------------------------")
print("Beginning Data Retrieval")
print("-----------------------------")
for i in cities:
    query_url = url + 'q=' + i + '&appid=' + weather_api_key
    data = requests.get(query_url).json()
    if(data['cod'] == 200):
        print("Processing data of " + str(i))
        final_cities_list.append(i)   
        country.append(data['sys']['country'])
        date.append(data['dt'])
        lat.append(data['coord']['lat'])
        lng.append(data['coord']['lon'])
        humidity.append(data['main']['humidity'])
        cloudiness.append(data['clouds']['all'])
        max_temp.append(data['main']['temp_max'])
        wind_speed.append(data['wind']['speed'])
    else:
        print("City not found. Skipping...")
print("-----------------------------")
print("Data Retreival complete")
print(f"Final list have {len(final_cities_list)} cities.")
print("-----------------------------")
# Out:
# -----------------------------
# Beginning Data Retrieval
# -----------------------------
# Processing data of tilichiki
# Processing data of bredasdorp
# Processing data of albany
# Processing data of victoria point
# Processing data of ust-tsilma
# City not found. Skipping...
# Processing data of mulatupo
# Processing data of mataura
# City not found. Skipping...
# Processing data of fairbanks
# Processing data of jamestown
# Processing data of atuona
# Processing data of nikki
# Processing data of hermanus
# Processing data of alekseyevsk
# Processing data of vao
# Processing data of urucui
# Processing data of dunedin
# Processing data of chumikan
# Processing data of awjilah
# Processing data of bilma
# Processing data of burnie
# Processing data of asbury park
# Processing data of mount isa
# Processing data of avarua
# Processing data of pandrup
# Processing data of ketchikan
# Processing data of saint-philippe
# Processing data of rikitea
# Processing data of hasaki
# Processing data of bonthe
# Processing data of kieta
# Processing data of thompson
# Processing data of kaitangata
# Processing data of inhambane
# Processing data of presidencia roque saenz pena
# Processing data of saldanha
# Processing data of busselton
# Processing data of puerto baquerizo moreno
# Processing data of port alfred
# Processing data of bluff
# City not found. Skipping...
# Processing data of port elizabeth
# Processing data of victoria
# Processing data of katsuura
# Processing data of laguna
# Processing data of huilong
# Processing data of cherskiy
# Processing data of codrington
# Processing data of spas-demensk
# Processing data of shu
# Processing data of yamada
# City not found. Skipping...
# Processing data of korla
# Processing data of vaini
# Processing data of esperance
# City not found. Skipping...
# Processing data of antofagasta
# Processing data of hilo
# Processing data of hobart
# Processing data of ahipara
# Processing data of los llanos de aridane
# City not found. Skipping...
# Processing data of muros
# City not found. Skipping...
# Processing data of punta arenas
# Processing data of grindavik
# Processing data of castro
# Processing data of fortuna
# Processing data of cayenne
# Processing data of nikolskoye
# Processing data of hamilton
# Processing data of chuy
# Processing data of tuatapere
# Processing data of dandong
# Processing data of butaritari
# Processing data of klaeng
# Processing data of geraldton
# Processing data of pacific grove
# Processing data of yerbogachen
# Processing data of khatanga
# Processing data of klaksvik
# Processing data of znamensk
# Processing data of tahta
# Processing data of east london
# Processing data of torbay
# Processing data of carnarvon
# Processing data of longyearbyen
# Processing data of narsaq
# Processing data of kavieng
# City not found. Skipping...
# Processing data of airai
# Processing data of tanda
# Processing data of kodiak
# Processing data of yulara
# Processing data of port macquarie
# Processing data of pestisani
# Processing data of barrow
# Processing data of severo-kurilsk
# Processing data of woodward
# Processing data of new norfolk
# Processing data of biu
# Processing data of saint george
# Processing data of phalaborwa
# City not found. Skipping...
# Processing data of torata
# Processing data of peniche
# Processing data of tommot
# Processing data of provideniya
# Processing data of kelheim
# Processing data of coihaique
# Processing data of baykit
# City not found. Skipping...
# Processing data of meulaboh
# Processing data of puerto ayora
# Processing data of norman wells
# Processing data of mumford
# Processing data of baiyin
# Processing data of hit
# Processing data of dongsheng
# Processing data of skibbereen
# Processing data of lebu
# Processing data of varena
# Processing data of college
# Processing data of dingle
# Processing data of ewa beach
# Processing data of ilulissat
# Processing data of yellowknife
# Processing data of piacabucu
# Processing data of beringovskiy
# Processing data of kerrville
# City not found. Skipping...
# Processing data of ginda
# City not found. Skipping...
# Processing data of mount gambier
# City not found. Skipping...
# Processing data of acajutla
# Processing data of tekanpur
# Processing data of mokrousovo
# Processing data of yanam
# City not found. Skipping...
# Processing data of bethel
# Processing data of maniitsoq
# Processing data of aykhal
# Processing data of kununurra
# Processing data of hithadhoo
# Processing data of antibes
# Processing data of oranjemund
# Processing data of mitsamiouli
# Processing data of vila franca do campo
# Processing data of vulcan
# Processing data of hualmay
# Processing data of ushuaia
# Processing data of sitka
# Processing data of cape town
# Processing data of ondjiva
# Processing data of talara
# Processing data of leningradskiy
# Processing data of kalach-na-donu
# Processing data of paita
# Processing data of saint-paul
# Processing data of kalmunai
# Processing data of tasiilaq
# Processing data of nanortalik
# Processing data of port hedland
# Processing data of vila velha
# Processing data of biltine
# Processing data of georgetown
# Processing data of tautira
# City not found. Skipping...
# Processing data of waipawa
# Processing data of tazovskiy
# Processing data of te anau
# Processing data of altay
# Processing data of guaira
# Processing data of tambo
# Processing data of bang saphan
# Processing data of celestun
# Processing data of ampanihy
# Processing data of kapaa
# Processing data of teguldet
# Processing data of urzhum
# Processing data of cururupu
# Processing data of lexington park
# City not found. Skipping...
# Processing data of pangnirtung
# Processing data of nuristan
# Processing data of camacha
# Processing data of zavodskoy
# Processing data of hervey bay
# Processing data of pisco
# Processing data of makakilo city
# Processing data of cidreira
# Processing data of morondava
# Processing data of dali
# Processing data of namibe
# Processing data of san andres
# Processing data of liverpool
# Processing data of touros
# Processing data of thouars
# Processing data of lorengau
# Processing data of pilar
# Processing data of verkhnevilyuysk
# Processing data of olafsvik
# Processing data of sao joao da barra
# Processing data of tiksi
# Processing data of vradiyivka
# Processing data of mursan
# Processing data of quelimane
# Processing data of dikson
# Processing data of alta gracia
# City not found. Skipping...
# Processing data of saskylakh
# City not found. Skipping...
# Processing data of tateyama
# Processing data of luderitz
# Processing data of tshikapa
# Processing data of umea
# Processing data of atar
# Processing data of yuanping
# Processing data of wattegama
# Processing data of tigre
# Processing data of denpasar
# Processing data of luzhou
# Processing data of chicama
# Processing data of akureyri
# Processing data of kaohsiung
# Processing data of labrea
# Processing data of hami
# Processing data of sinazongwe
# Processing data of svetlaya
# Processing data of makungu
# Processing data of carman
# Processing data of luanda
# Processing data of tatawin
# Processing data of arraial do cabo
# Processing data of jumla
# Processing data of moa
# Processing data of carballo
# Processing data of srikakulam
# Processing data of buraydah
# Processing data of jining
# Processing data of villazon
# Processing data of bintulu
# Processing data of agadir
# Processing data of san quintin
# Processing data of buchanan
# Processing data of puerto madryn
# Processing data of morki
# Processing data of mahebourg
# Processing data of acapulco
# City not found. Skipping...
# Processing data of diamantino
# Processing data of tuktoyaktuk
# Processing data of byron bay
# Processing data of navahrudak
# Processing data of saint-joseph
# Processing data of san rafael
# Processing data of seydi
# Processing data of mareeba
# Processing data of labuhan
# Processing data of dubbo
# City not found. Skipping...
# Processing data of tabora
# Processing data of bambous virieux
# Processing data of fort nelson
# Processing data of artesia
# City not found. Skipping...
# Processing data of sitarganj
# Processing data of cam ranh
# City not found. Skipping...
# Processing data of qaanaaq
# Processing data of port blair
# Processing data of apache junction
# Processing data of praya
# Processing data of vredendal
# Processing data of sobolevo
# Processing data of kondinskoye
# Processing data of shirochanka
# Processing data of vanderhoof
# City not found. Skipping...
# Processing data of seoul
# City not found. Skipping...
# Processing data of chiusi
# Processing data of portel
# Processing data of chardara
# Processing data of teluk nibung
# Processing data of salinas
# Processing data of la ronge
# Processing data of xam nua
# Processing data of kapit
# Processing data of aklavik
# City not found. Skipping...
# Processing data of bandarbeyla
# Processing data of cabo san lucas
# Processing data of tupiza
# City not found. Skipping...
# Processing data of tacuarembo
# Processing data of matucana
# Processing data of beloha
# Processing data of udachnyy
# Processing data of ginir
# Processing data of gabriel leyva solano
# Processing data of kyabe
# Processing data of kibala
# Processing data of royan
# City not found. Skipping...
# Processing data of mayo
# Processing data of gap
# Processing data of auki
# Processing data of goroka
# Processing data of ouegoa
# Processing data of sampit
# City not found. Skipping...
# Processing data of faanui
# Processing data of hadgaon
# Processing data of saint-francois
# Processing data of mar del plata
# Processing data of clyde river
# Processing data of muli
# Processing data of damghan
# Processing data of samarai
# City not found. Skipping...
# Processing data of san patricio
# Processing data of mitu
# Processing data of comodoro rivadavia
# Processing data of kruisfontein
# Processing data of praia
# Processing data of jelenia gora
# Processing data of stawell
# Processing data of grand gaube
# Processing data of lavrentiya
# Processing data of ouesso
# Processing data of raga
# Processing data of saint-pierre
# Processing data of marawi
# Processing data of lewistown
# Processing data of gold coast
# Processing data of garwolin
# Processing data of vuktyl
# Processing data of arlit
# Processing data of dolny kubin
# Processing data of padang
# Processing data of toora-khem
# Processing data of taltal
# Processing data of eureka
# Processing data of bengkulu
# Processing data of ardakan
# Processing data of alice springs
# Processing data of joshimath
# Processing data of sabha
# Processing data of vestmannaeyjar
# Processing data of sao filipe
# Processing data of ngunguru
# Processing data of chilliwack
# Processing data of ancud
# Processing data of najran
# Processing data of upernavik
# Processing data of tabou
# Processing data of matinhos
# Processing data of quesnel
# Processing data of ceres
# Processing data of zilair
# Processing data of betafo
# Processing data of avera
# Processing data of tunceli
# Processing data of bilibino
# Processing data of belmonte
# Processing data of tatvan
# Processing data of valente
# Processing data of mahibadhoo
# City not found. Skipping...
# Processing data of pevek
# Processing data of taoudenni
# Processing data of ganzhou
# Processing data of terracina
# Processing data of imbituba
# Processing data of vostok
# Processing data of matara
# City not found. Skipping...
# Processing data of tarakan
# City not found. Skipping...
# Processing data of waitara
# Processing data of zhytomyr
# Processing data of viedma
# Processing data of hobyo
# Processing data of nemuro
# Processing data of ponta do sol
# Processing data of okhotsk
# Processing data of leshukonskoye
# Processing data of zavetnoye
# Processing data of oksfjord
# Processing data of romny
# Processing data of santa clara
# Processing data of sisimiut
# Processing data of ozernovskiy
# Processing data of karratha
# Processing data of nambour
# Processing data of nichinan
# Processing data of asau
# Processing data of lyuban
# Processing data of maldonado
# Processing data of batemans bay
# Processing data of banfora
# Processing data of ribeira grande
# Processing data of half moon bay
# Processing data of inta
# Processing data of sambava
# Processing data of finale emilia
# Processing data of daru
# Processing data of onega
# Processing data of ayan
# Processing data of la grande
# Processing data of nelson bay
# Processing data of brae
# Processing data of guanica
# Processing data of lompoc
# Processing data of talcahuano
# Processing data of townsville
# Processing data of zhezkazgan
# Processing data of rio grande
# Processing data of makushino
# Processing data of huntsville
# Processing data of ilheus
# Processing data of shaunavon
# Processing data of zhigansk
# Processing data of alyangula
# Processing data of kismayo
# Processing data of bobo dioulasso
# Processing data of onalaska
# Processing data of lodja
# Processing data of wagar
# Processing data of saint-louis
# Processing data of sistranda
# Processing data of lubao
# Processing data of paamiut
# Processing data of hofn
# City not found. Skipping...
# Processing data of smithers
# Processing data of gandajika
# Processing data of port hardy
# Processing data of alofi
# Processing data of nha trang
# Processing data of punta de piedra
# Processing data of aksarka
# Processing data of parana
# Processing data of kontagora
# Processing data of bara
# Processing data of bathsheba
# Processing data of rong kwang
# Processing data of vardo
# Processing data of mackay
# Processing data of nizwa
# Processing data of encruzilhada
# Processing data of krasnystaw
# Processing data of cap malheureux
# Processing data of port keats
# City not found. Skipping...
# Processing data of yar-sale
# Processing data of wanning
# Processing data of iqaluit
# Processing data of port moresby
# Processing data of innisfail
# Processing data of iquitos
# Processing data of taua
# Processing data of chiredzi
# Processing data of nauchnyy gorodok
# Processing data of haysville
# Processing data of san borja
# Processing data of mercedes
# Processing data of eyl
# City not found. Skipping...
# Processing data of kavaratti
# Processing data of marovoay
# Processing data of petropavl
# Processing data of port lincoln
# Processing data of qandala
# Processing data of bolshevik
# Processing data of bardiyah
# Processing data of yangambi
# Processing data of uvinza
# Processing data of braganca
# Processing data of souillac
# Processing data of winnemucca
# Processing data of faya
# Processing data of maun
# Processing data of linqiong
# City not found. Skipping...
# Processing data of hovd
# Processing data of rosarito
# Processing data of shetpe
# Processing data of mabaruma
# Processing data of oranjestad
# Processing data of bahile
# Processing data of ugoofaaru
# Processing data of marzuq
# Processing data of kabo
# Processing data of norden
# Processing data of yining
# City not found. Skipping...
# City not found. Skipping...
# Processing data of ometepec
# Processing data of shubarkuduk
# Processing data of chokurdakh
# Processing data of turukhansk
# City not found. Skipping...
# Processing data of sobradinho
# Processing data of shelburne
# Processing data of silver city
# Processing data of hambantota
# Processing data of gizo
# City not found. Skipping...
# Processing data of wewak
# Processing data of harper
# Processing data of aksu
# Processing data of buriti dos lopes
# Processing data of biak
# Processing data of areosa
# Processing data of benguela
# Processing data of husavik
# Processing data of homer
# Processing data of virden
# Processing data of porto novo
# Processing data of vagay
# Processing data of magadan
# Processing data of naifaru
# Processing data of colares
# City not found. Skipping...
# Processing data of buala
# Processing data of margate
# Processing data of naustdal
# Processing data of misratah
# Processing data of mersing
# Processing data of trairi
# Processing data of loreto
# City not found. Skipping...
# Processing data of ornskoldsvik
# Processing data of lyngseidet
# Processing data of guerrero negro
# City not found. Skipping...
# Processing data of mayumba
# Processing data of kaeo
# Processing data of kirillov
# Processing data of nuuk
# Processing data of sterling
# Processing data of dudinka
# Processing data of rundu
# City not found. Skipping...
# Processing data of daltenganj
# Processing data of nishihara
# Processing data of flinders
# Processing data of solnechnyy
# Processing data of cairns
# Processing data of worthington
# Processing data of moses lake
# Processing data of mount pleasant
# Processing data of flin flon
# Processing data of tubuala
# Processing data of gwembe
# Processing data of acarau
# Processing data of wenling
# Processing data of ulundi
# Processing data of kajaani
# Processing data of laubach
# City not found. Skipping...
# Processing data of santa maria
# Processing data of yarada
# Processing data of yumen
# Processing data of lagoa
# City not found. Skipping...
# Processing data of cherepovets
# Processing data of mehamn
# Processing data of stranraer
# City not found. Skipping...
# Processing data of gigmoto
# Processing data of ondangwa
# Processing data of hsinchu
# Processing data of tabuk
# Processing data of constitucion
# Processing data of kuytun
# Processing data of balestrand
# Processing data of aktau
# Processing data of bereda
# Processing data of amiens
# Processing data of donskoy
# Processing data of wanaka
# Processing data of tomatlan
# Processing data of araouane
# Processing data of jiangyou
# Processing data of haines junction
# Processing data of zharkent
# Processing data of el alto
# Processing data of dhule
# Processing data of coahuayana
# Processing data of naze
# Processing data of portland
# Processing data of karangasem
# Processing data of berlevag
# Processing data of atasu
# Processing data of tura
# Processing data of caravelas
# Processing data of ostrovnoy
# Processing data of amuntai
# Processing data of lazaro cardenas
# Processing data of tamandare
# Processing data of lumby
# Processing data of mandalgovi
# Processing data of maceio
# Processing data of poronaysk
# Processing data of samandag
# Processing data of atikokan
# Processing data of guarapari
# Processing data of zakamensk
# Processing data of jaru
# Processing data of karpogory
# Processing data of sal rei
# Processing data of juegang
# -----------------------------
# Data Retreival complete
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-10-977a88631c46> in <module>
#      32 print("-----------------------------")
#      33 print("Data Retreival complete")
# ---> 34 print(f"Final list have {len(citiesList)}")
#      35 print("-----------------------------")
#
# NameError: name 'citiesList' is not defined

# %%
cities_dict = {}
cities_dict = list(zip(final_cities_list,country,
                       date,lat,lng,
                       humidity,cloudiness,max_temp,wind_speed))
df = pd.DataFrame(cities_dict,columns=['City','Country',
                                       'Date','Lat','Lng',
                                       'Humidity','Cloudiness','Max Temp','Wind Speed'])
df.head()
# Out:
#              City Country        Date    Lat     Lng  Humidity  Cloudiness  \
# 0       tilichiki      RU  1589437628  60.47  166.10        91          21
# 1      bredasdorp      ZA  1589437630 -34.53   20.04        87           0
# 2          albany      US  1589437634  42.60  -73.97        84           0
# 3  victoria point      AU  1589437637 -27.58  153.30        77          75
# 4      ust-tsilma      RU  1589437638  65.44   52.15        64         100
#
#    Max Temp  Wind Speed
# 0    274.27        4.78
# 1    282.15        2.10
# 2    279.26        1.85
# 3    293.71        2.60
# 4    279.05        6.59

# %%
df.count()
# Out:
# City          570
# Country       570
# Date          570
# Lat           570
# Lng           570
# Humidity      570
# Cloudiness    570
# Max Temp      570
# Wind Speed    570
# dtype: int64

# %% [markdown]
# ## Missing things :
# * Change date
# * Graphs
# * Save DF in csv
